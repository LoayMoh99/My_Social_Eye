# %%
from commonfunctions import *
import math
from skimage import filters
from skimage import data
from skimage.color import rgb2gray

import skfuzzy as fuzz
import dlib

# %%
img = io.imread('./test_images/00513_940519_fa_a.ppm')
img = (resize(img,(480,360,3),anti_aliasing=True)*255).astype("uint8")

detector = dlib.get_frontal_face_detector()
dets = detector(img, 1)
print("Number of faces detected: {}".format(len(dets)))

for k, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        k, d.left(), d.top(), d.right(), d.bottom()))

face = img[d.top():d.bottom(), d.left():d.right()]

data = np.reshape(face, (-1,3))
print(data.shape)
data = np.float32(data)

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
flags = cv2.KMEANS_RANDOM_CENTERS
compactness,labels,centers = cv2.kmeans(data,1,None,criteria,10,flags)

print('Dominant color is: bgr({})'.format(centers[0].astype(np.int32)))
# Out:
# Number of faces detected: 1
# Detection 0: Left: 43 Top: 142 Right: 266 Bottom: 365
# (49729, 3)
# Dominant color is: bgr([125  98  78])

# %%
# img = io.imread('./test_images/00513_940519_fa_a.ppm')
img = io.imread('./test_images/00533_940519_fa_a.ppm')
img = (resize(img,(480,360,3),anti_aliasing=True)*255).astype("uint8")

detector = dlib.get_frontal_face_detector()
dets = detector(img, 1)
print("Number of faces detected: {}".format(len(dets)))

for k, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        k, d.left(), d.top(), d.right(), d.bottom()))

face = img[d.top():d.bottom(), d.left():d.right()]

showHist(face[:,:,0])
showHist(face[:,:,1])
showHist(face[:,:,2])
print(np.average(face[:,:,0]))
print(np.average(face[:,:,1]))
print(np.average(face[:,:,2]))
# show_images([face[:,:,0],face[:,:,1],face[:,:,2]],["red","green","blue"])
show_images([face])
# Out:
# Number of faces detected: 1
# Detection 0: Left: 68 Top: 142 Right: 291 Bottom: 365
# 91.25067867843713
# 78.01882201532305
# 63.079370186410344

# %%
img = io.imread('./test_images/00003_940307_fa_a.ppm')
# img = io.imread('./test_images/00533_940519_fa_a.ppm')
img = (resize(img,(480,360,3),anti_aliasing=True)*255).astype("uint8")

detector = dlib.get_frontal_face_detector()
dets = detector(img, 1)
print("Number of faces detected: {}".format(len(dets)))

for k, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        k, d.left(), d.top(), d.right(), d.bottom()))

face = img[d.top():d.bottom(), d.left():d.right()]

showHist(face[:,:,0])
showHist(face[:,:,1])
showHist(face[:,:,2])

print(np.average(face[:,:,0]))
print(np.average(face[:,:,1]))
print(np.average(face[:,:,2]))

show_images([face])
# show_images([face[:,:,0],face[:,:,1],face[:,:,2]],["red","green","blue"])
# Out:
# Number of faces detected: 1
# Detection 0: Left: 68 Top: 167 Right: 291 Bottom: 390
# 96.98970419674636
# 80.62209173721571
# 51.363791751292005

# %%
img = io.imread('./test_images/00513_940519_fa_a.ppm')
# img = io.imread('./test_images/00533_940519_fa_a.ppm')
img = (resize(img,(480,360,3),anti_aliasing=True)*255).astype("uint8")

detector = dlib.get_frontal_face_detector()
dets = detector(img, 1)
print("Number of faces detected: {}".format(len(dets)))

for k, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        k, d.left(), d.top(), d.right(), d.bottom()))

face = img[d.top():d.bottom(), d.left():d.right()]

showHist(face[:,:,0])
showHist(face[:,:,1])
showHist(face[:,:,2])

print(np.average(face[:,:,0]))
print(np.average(face[:,:,1]))
print(np.average(face[:,:,2]))

show_images([face])
# Out:
# Number of faces detected: 1
# Detection 0: Left: 43 Top: 142 Right: 266 Bottom: 365
# 125.66717609443182
# 98.9255967342999
# 78.84542218826037

# %%
img = io.imread('./test_images/colorferet_5.ppm')
# img = io.imread('./test_images/00533_940519_fa_a.ppm')
img = (resize(img,(480,360,3),anti_aliasing=True)*255).astype("uint8")

detector = dlib.get_frontal_face_detector()
dets = detector(img, 1)
print("Number of faces detected: {}".format(len(dets)))

for k, d in enumerate(dets):
    print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
        k, d.left(), d.top(), d.right(), d.bottom()))

face = img[d.top():d.bottom(), d.left():d.right()]

showHist(face[:,:,0])
showHist(face[:,:,1])
showHist(face[:,:,2])

print(np.average(face[:,:,0]))
print(np.average(face[:,:,1]))
print(np.average(face[:,:,2]))

show_images([face])
# Out:
# Number of faces detected: 1
# Detection 0: Left: 98 Top: 133 Right: 253 Bottom: 288
# 94.64670135275755
# 70.67446409989594
# 50.73327783558793
